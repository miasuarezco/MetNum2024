# %% [markdown]
# <a href="https://colab.research.google.com/github/alienigena264/MetNumUN2024I/blob/main/Lab/Lab4/jgarciaotGroup19SymPyLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NumericalMethods Lab4 2023-II
# ## Student: Juan Pablo Garcia Otalora

# %% [markdown]
# # SymPyLab
#
# My last digit ID: 5
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$

# %% [markdown]
# **My polynomial degree 10**

# %% [markdown]
# - (x-48)(x-22)(x-73)(x-44)(x-25)(x-12)(x-52)(x-83)(x-42)(x-15)
# - x^10 - 416 x^9 + 75326 x^8 - 7806068 x^7 + 511797797 x^6 - 22137196508 x^5 + 638267760220 x^4 - 12083997244176 x^3 + 143448211741248 x^2 - 962310232984320 x + 2766831395328000

# %% [markdown]
# ![imagen_2023-09-10_192632468.png](data:image/png;base64,...)

# %% [markdown]
# **My polynomial divided by a root**

# %% [markdown]
# x^10 - 416 x^9 + 75326 x^8 - 7806068 x^7 + 511797797 x^6 - 22137196508 x^5 + 638267760220 x^4 - 12083997244176 x^3 + 143448211741248 x^2 - 962310232984320 x + 2766831395328000/(x- 12)

# %% [markdown]
# ![imagen_2023-09-10_194928732.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **My polynomial divided by a NON root**

# %% [markdown]
# - x^10 - 416 x^9 + 75326 x^8 - 7806068 x^7 + 511797797 x^6 - 22137196508 x^5 + 638267760220 x^4 - 12083997244176 x^3 + 143448211741248 x^2 - 962310232984320 x + 2766831395328000/(x- 55)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Sympy divide my polynomial by all 10 roots**

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 - 416*x**9 + 75326*x**8 - 7806068*x**7 + 511797797*x**6 - 22137196508*x**5 + 638267760220*x**4 - 12083997244176*x**3 + 143448211741248*x**2 - 962310232984320*x + 2766831395328000

p, r = div(p,  x-48)
print("Primera Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-22)
print("Segunda Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-73)
print("Tercera Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-44)
print("Cuarta Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-25)
print("Quinta Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-12)
print("Sexta Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-52)
print("Septima Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-83)
print("Octava Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-42)
print("Novena Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-15)
print("Decima Raiz")
print("Resultado: ", p)
print("Residuo: ", r)
# Out:
# Primera Raiz
# Resultado:  x**9 - 368*x**8 + 57662*x**7 - 5038292*x**6 + 269959781*x**5 - 9179127020*x**4 + 197669663260*x**3 - 2595853407696*x**2 + 18847248171840*x - 57642320736000
# Residuo:  0
# Segunda Raiz
# Resultado:  x**8 - 346*x**7 + 50050*x**6 - 3937192*x**5 + 183341557*x**4 - 5145612766*x**3 + 84466182408*x**2 - 737597394720*x + 2620105488000
# Residuo:  0
# Tercera Raiz
# Resultado:  x**7 - 273*x**6 + 30121*x**5 - 1738359*x**4 + 56441350*x**3 - 1025394216*x**2 + 9612404640*x - 35891856000
# Residuo:  0
# Cuarta Raiz
# Resultado:  x**6 - 229*x**5 + 20045*x**4 - 856379*x**3 + 18760674*x**2 - 199924560*x + 815724000
# Residuo:  0
# Quinta Raiz
# Resultado:  x**5 - 204*x**4 + 14945*x**3 - 482754*x**2 + 6691824*x - 32628960
# Residuo:  0
# Sexta Raiz
# Resultado:  x**4 - 192*x**3 + 12641*x**2 - 331062*x + 2719080
# Residuo:  0
# Septima Raiz
# Resultado:  x**3 - 140*x**2 + 5361*x - 52290
# Residuo:  0
# Octava Raiz
# Resultado:  x**2 - 57*x + 630
# Residuo:  0
# Novena Raiz
# ...

# %% [markdown]
# **Sympy divides my polynomial by a NO root**

# %%
p = x**10 - 416*x**9 + 75326*x**8 - 7806068*x**7 + 511797797*x**6 - 22137196508*x**5 + 638267760220*x**4 - 12083997244176*x**3 + 143448211741248*x**2 - 962310232984320*x + 2766831395328000

p, r = div(p,  x-54)
print("No es Raiz x-54")
print("Resultado: ", p)
print("Residuo: ", r)
# Out:
# No es Raiz x-54
# Resultado:  x**9 - 362*x**8 + 55778*x**7 - 4794056*x**6 + 252918773*x**5 - 8479582766*x**4 + 180370290856*x**3 - 2344001537952*x**2 + 16872128691840*x - 51215283624960
# Residuo:  1206079580160

# %% [markdown]
# **SymPy’s polynomial simple univariate polynomial factorization**

# %% [markdown]
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x^10 - 416 x^9 + 75326 x^8 - 7806068 x^7 + 511797797 x^6 - 22137196508 x^5 + 638267760220 x^4 - 12083997244176 x^3 + 143448211741248 x^2 - 962310232984320 x + 2766831395328000)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 416*x**9 + 75326*x**8 - 7806068*x**7 + 511797797*x**6 - 22137196508*x**5 + 638267760220*x**4 - 12083997244176*x**3 + 143448211741248*x**2 - 962310232984320*x + 2766831395328000)
# Out:
# (x - 83)*(x - 73)*(x - 52)*(x - 48)*(x - 44)*(x - 42)*(x - 25)*(x - 22)*(x - 15)*(x - 12)

# %% [markdown]
# **SymPy’s solvers**

# %% [markdown]
# - https://docs.sympy.org/latest/tutorial/solvers.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 416*x**9 + 75326*x**8 - 7806068*x**7 + 511797797*x**6 - 22137196508*x**5 + 638267760220*x**4 - 12083997244176*x**3 + 143448211741248*x**2 - 962310232984320*x + 2766831395328000, 0), x)
# Out:
# {12, 15, 22, 25, 42, 44, 48, 52, 73, 83}

# %% [markdown]
# ## Symbolic ecuations solutions:

# %% [markdown]
# x^2 π - (π + sqrt(31)) + (sqrt(54) + π) = 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(x**2*pi-(pi+sqrt(31))+(sqrt(54)+pi), 0), x)
# Out:
# {-sqrt(-3*sqrt(6) + sqrt(31))/sqrt(pi), sqrt(-3*sqrt(6) + sqrt(31))/sqrt(pi)}

# %% [markdown]
# - Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# - Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# - Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ## Factorizacion with modulus:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')

factor(x**10 - 416*x**9 + 75326*x**8 - 7806068*x**7 + 511797797*x**6 - 22137196508*x**5 + 638267760220*x**4 - 12083997244176*x**3 + 143448211741248*x**2 - 962310232984320*x + 2766831395328000,domain='GF(2)')
# Out:
# x**6*(x + 1)**4

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
#
# ### My own example was made using:
# - x = 26 + I*x1,y = 65 + I*y1, z = 23 + I*z1, x * y * z

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, y1, z1 = symbols("x1 y1 z1", real=True)
x = 26 + I*x1
y = 65 + I*y1
z = 23 + I*z1

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (I*x1 + 26)*(I*y1 + 65)*(I*z1 + 23)
# -I*x1*y1*z1 - 23*x1*y1 - 65*x1*z1 + 1495*I*x1 - 26*y1*z1 + 598*I*y1 + 1690*I*z1 + 38870
# -I*x1*y1*z1 - 23*x1*y1 - 65*x1*z1 + 1495*I*x1 - 26*y1*z1 + 598*I*y1 + 1690*I*z1 + 38870
# -I*x1*y1*z1 - 23*x1*y1 - 65*x1*z1 + 1495*I*x1 - 26*y1*z1 + 598*I*y1 + 1690*I*z1 + 38870
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Try the same question asked in Wolfram Alpha in ChatGPT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
from math import pi
x = Symbol('x')
integrate((x+2)/((x-1)*(x-3)), x)
# Out:
# 5*log(x - 3)/2 - 3*log(x - 1)/2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin, cos
x = Symbol('x')
integrate(cos(x) + (x**2 + x - (1/x)), (x,1,5))
# Out:
# -log(5) + sin(5) - sin(1) + 160/3

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(x**2 * sin(x)**3, (x,1,5)))
# Out:
# -15.4297821533056

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(cos(x) + (x**2 + x - (1/x)), (x,1,5)))
# Out:
# 49.9235001614282
